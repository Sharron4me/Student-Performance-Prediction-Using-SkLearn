# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv('Target.csv')

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
df.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
sex_c= list(set(df.sex))

# %%
le = LabelEncoder()

# %%
le.fit(sex_c)
# Out:
# LabelEncoder()

# %%
le.classes_
# Out:
# array(['F', 'M'], dtype='<U1')

# %%
df.sex = le.transform(df.sex)

# %%
df.head()
# Out:
#   school  sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP    0   18       U     GT3       A     4     4  at_home   teacher
# 1     GP    0   17       U     GT3       T     1     1  at_home     other
# 2     GP    0   15       U     LE3       T     1     1  at_home     other
# 3     GP    0   15       U     GT3       T     4     2   health  services
# 4     GP    0   16       U     GT3       T     3     3    other     other
#
#    ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0  ...      4        3      4     1     1      3        6   5   6   6
# 1  ...      5        3      3     1     1      3        4   5   5   6
# 2  ...      4        3      2     2     3      3       10   7   8  10
# 3  ...      3        2      2     1     1      5        2  15  14  15
# 4  ...      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
school_c= list(set(df.school))

# %%
le.fit(school_c)
# Out:
# LabelEncoder()

# %%
df.school = le.transform(df.school)

# %%
df.head()
# Out:
#    school  sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0       0    0   18       U     GT3       A     4     4  at_home   teacher
# 1       0    0   17       U     GT3       T     1     1  at_home     other
# 2       0    0   15       U     LE3       T     1     1  at_home     other
# 3       0    0   15       U     GT3       T     4     2   health  services
# 4       0    0   16       U     GT3       T     3     3    other     other
#
#    ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0  ...      4        3      4     1     1      3        6   5   6   6
# 1  ...      5        3      3     1     1      3        4   5   5   6
# 2  ...      4        3      2     2     3      3       10   7   8  10
# 3  ...      3        2      2     1     1      5        2  15  14  15
# 4  ...      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
address_c  = list(set(df.address))

# %%
le.fit(address_c)
# Out:
# LabelEncoder()

# %%
df.address = le.transform(df.address)

# %%
df.head()
# Out:
#    school  sex  age  address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0       0    0   18        1     GT3       A     4     4  at_home   teacher
# 1       0    0   17        1     GT3       T     1     1  at_home     other
# 2       0    0   15        1     LE3       T     1     1  at_home     other
# 3       0    0   15        1     GT3       T     4     2   health  services
# 4       0    0   16        1     GT3       T     3     3    other     other
#
#    ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0  ...      4        3      4     1     1      3        6   5   6   6
# 1  ...      5        3      3     1     1      3        4   5   5   6
# 2  ...      4        3      2     2     3      3       10   7   8  10
# 3  ...      3        2      2     1     1      5        2  15  14  15
# 4  ...      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
le.fit(df.Mjob)
# Out:
# LabelEncoder()

# %%
df.Mjob = le.transform(df.Mjob)

# %%
df.head()
# Out:
#    school  sex  age  address famsize Pstatus  Medu  Fedu  Mjob      Fjob  ...  \
# 0       0    0   18        1     GT3       A     4     4     0   teacher  ...
# 1       0    0   17        1     GT3       T     1     1     0     other  ...
# 2       0    0   15        1     LE3       T     1     1     0     other  ...
# 3       0    0   15        1     GT3       T     4     2     1  services  ...
# 4       0    0   16        1     GT3       T     3     3     2     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
le.fit(df.Fjob)
df.Fjob = le.transform(df.Fjob)
df.head()
# Out:
#    school  sex  age  address famsize Pstatus  Medu  Fedu  Mjob  Fjob  ...  \
# 0       0    0   18        1     GT3       A     4     4     0     4  ...
# 1       0    0   17        1     GT3       T     1     1     0     2  ...
# 2       0    0   15        1     LE3       T     1     1     0     2  ...
# 3       0    0   15        1     GT3       T     4     2     1     3  ...
# 4       0    0   16        1     GT3       T     3     3     2     2  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
le.fit(df.famsize)
df.famsize = le.transform(df.famsize)
df.head()
# Out:
#    school  sex  age  address  famsize Pstatus  Medu  Fedu  Mjob  Fjob  ...  \
# 0       0    0   18        1        0       A     4     4     0     4  ...
# 1       0    0   17        1        0       T     1     1     0     2  ...
# 2       0    0   15        1        1       T     1     1     0     2  ...
# 3       0    0   15        1        0       T     4     2     1     3  ...
# 4       0    0   16        1        0       T     3     3     2     2  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
le.fit(df.Pstatus)
df.Pstatus = le.transform(df.Pstatus)
df.head()
# Out:
#    school  sex  age  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  ...  \
# 0       0    0   18        1        0        0     4     4     0     4  ...
# 1       0    0   17        1        0        1     1     1     0     2  ...
# 2       0    0   15        1        1        1     1     1     0     2  ...
# 3       0    0   15        1        0        1     4     2     1     3  ...
# 4       0    0   16        1        0        1     3     3     2     2  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
le.fit(df.reason)
df.reason = le.transform(df.reason)
df.head()
# Out:
#    school  sex  age  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  ...  \
# 0       0    0   18        1        0        0     4     4     0     4  ...
# 1       0    0   17        1        0        1     1     1     0     2  ...
# 2       0    0   15        1        1        1     1     1     0     2  ...
# 3       0    0   15        1        0        1     4     2     1     3  ...
# 4       0    0   16        1        0        1     3     3     2     2  ...
#
#    famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0       4        3      4     1     1      3        6   5   6   6
# 1       5        3      3     1     1      3        4   5   5   6
# 2       4        3      2     2     3      3       10   7   8  10
# 3       3        2      2     1     1      5        2  15  14  15
# 4       4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
df.guardian
le.fit(df.guardian)
df.guardian = le.transform(df.guardian)
df.head()
# Out:
#    school  sex  age  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  ...  \
# 0       0    0   18        1        0        0     4     4     0     4  ...
# 1       0    0   17        1        0        1     1     1     0     2  ...
# 2       0    0   15        1        1        1     1     1     0     2  ...
# 3       0    0   15        1        0        1     4     2     1     3  ...
# 4       0    0   16        1        0        1     3     3     2     2  ...
#
#    famrel  freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0       4         3      4     1     1      3        6   5   6   6
# 1       5         3      3     1     1      3        4   5   5   6
# 2       4         3      2     2     3      3       10   7   8  10
# 3       3         2      2     1     1      5        2  15  14  15
# 4       4         3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
df.dtypes
# Out:
# school         int32
# sex            int32
# age            int64
# address        int32
# famsize        int32
# Pstatus        int32
# Medu           int64
# Fedu           int64
# Mjob           int32
# Fjob           int32
# reason         int32
# guardian       int32
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# dtype: object

# %%
lis = ['schoolsup','famsup','paid','activities','nursery','higher','internet','romantic']
for k in lis:
    le.fit(df[k])
    df[k]=le.transform(df[k])

# %%
y=df.G3
df = df.drop(['G3'],axis=1)

# %%
df.dtypes

from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(df, y, test_size=0.33, random_state=42)

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
model  = DecisionTreeRegressor(random_state=1)

# %%
model.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=1, splitter='best')

# %%
prediction = model.predict(X_test)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(prediction,'b',np.array(y_test),'ro')

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(prediction,y_test)
# Out:
# 6.251908396946565
